# %%
import population_spider
import population_analysis
import pandas as pd
import matplotlib.pyplot as plt
str_data_path = "data\\"
plt.rcParams['font.sans-serif'] = ['KaiTi']
plt.rcParams['font.serif'] = ['KaiTi']
plt.rcParams['font.sans-serif'] = ['simhei']

# %%
data = pd.read_excel("population.xlsx")
data["年份"] = pd.to_datetime(data["年份"],format="%Y")
data = data.set_index("年份",drop=True)
data = data[~data.index.duplicated(keep="first")]
data.tail(1)
# Out:
#             年末总人口(万人)  男性人口(万人)  女性人口(万人)  城镇人口(万人)  乡村人口(万人)  人口出生率(‰)  \
# 年份
# 2019-01-01   140005.0   71527.0   68478.0   84843.0   55162.0     10.48
#
#             人口死亡率(‰)  人口自然增长率(‰)  年末总人口(万人).1  0-14岁人口(万人)  15-64岁人口(万人)  \
# 年份
# 2019-01-01      7.14        3.34     140005.0      25061.0       97341.0
#
#             65岁及以上人口(万人)    总抚养比(%)   少儿抚养比(%)  老年抚养比(%)
# 年份
# 2019-01-01       17603.0  43.829424  25.745575  18.08385

# %%
plt.rcParams.update({'font.size': 24})
data[[\
      #"年末总人口(万人)"\
      #,"男性人口(万人)"\
      #,"女性人口(万人)"\
      #,"城镇人口(万人)"\
      #,"乡村人口(万人)"\
      #,"0-14岁人口(万人)"\
      #,"15-64岁人口(万人)"\
      #,"65岁及以上人口(万人)"\
      "总抚养比(%)"\
      ,"少儿抚养比(%)"\
      ,"老年抚养比(%)"
     ]].plot(figsize = (25,10))
